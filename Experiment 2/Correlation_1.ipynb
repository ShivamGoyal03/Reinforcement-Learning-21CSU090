# %%
import numpy as np
import matplotlib

# %%
np.random.seed(1)

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0,50,1000)

# %%
# Positive coorelation with some noise
y = x + np.random.normal(0, 10, 1000)

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %% [markdown]
# The coorelation is 0.815, a strong positive correlation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %% [markdown]
# Positive Correlation

# %%
# 1000 random integers between 0 and 50
x1 = np.random.randint(0,100,1000)

# %%
# Positive coorelation with some noise
y1 = x - np.random.normal(0, 10, 1000)

# %%
np.corrcoef(x1, y1)
# Out:
# array([[1.        , 0.01339372],
#        [0.01339372, 1.        ]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x1,y1)
plt.show()

# %% [markdown]
# Zero Correlation

# %%
np.random.seed(123)
x2 = np.random.randint(0, 50, 1000)

# %%
y2 = 100 - x + np.random.normal(0,5,1000)

# %%
np.corrcoef(x2, y2)
# Out:
# array([[1.        , 0.00760457],
#        [0.00760457, 1.        ]])

# %% [markdown]
# Oue correlation is now negative and close to 1. Let's take a look at what this looks like graphically.

# %%
plt.scatter(x2,y2)
plt.show()

# %%
x3 = np.random.randint(0, 50, 1000)
y3 = x3 + np.random.normal(0, 25, 1000)

z = np.random.normal(0, 10, 1000)

# %%
plt.scatter(x3,y3)
plt.scatter(x3,y3)
plt.scatter(y3,z)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd

df = pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.normal(0,10,1000)
df['c'] = 100 - df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.813746 -0.946088  0.038844
# b  0.813746  1.000000 -0.774997  0.061222
# c -0.946088 -0.774997  1.000000 -0.041861
# d  0.038844  0.061222 -0.041861  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()

# %%
import seaborn as sns

# Correlation matrix
corr = df.corr()
sns.heatmap(corr,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >
